# %%
print("hello")
# Out:
# hello

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="OgZ7hArcwtwkxZQT3FgP")
project = rf.workspace("jainam-doshi-ajldi").project("box_count-cmzxw")
dataset = project.version(3).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.200, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Box_Count-3 in yolov8:: 100%|██████████| 88/88 [00:00<00:00, 429.64it/s]

# %%
# !yolo task=detect mode = train model=yolov8m.pt data=Box_Count-3/data.yaml epochs = 10 imgsz = 640
# Out:
# Ultralytics YOLOv8.0.200  Python-3.11.4 torch-2.1.0+cpu CPU (Intel Core(TM) i5-9300H 2.40GHz)
# ...

# %%
# !yolo task=detect mode = predict model=runs/detect/train8/weights/best.pt conf = 0.5 source = Box_Count-3/valid/images
# Out:
# Ultralytics YOLOv8.0.200  Python-3.11.4 torch-2.1.0+cpu CPU (Intel Core(TM) i5-9300H 2.40GHz)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/7 d:\PYTHON PROJECTS\Box_Counting\Box_Count-3\valid\images\10_jpeg.rf.4e915c7b1ca01f624dd936f3226bb346.jpg: 448x640 4 Boxess, 690.9ms
# image 2/7 d:\PYTHON PROJECTS\Box_Counting\Box_Count-3\valid\images\17_jpeg.rf.57bfd6adb1e05bcf832a77f0eb303453.jpg: 384x640 2 Boxess, 597.4ms
# image 3/7 d:\PYTHON PROJECTS\Box_Counting\Box_Count-3\valid\images\27_jpeg.rf.896ea8a46197e234babefe61321d542a.jpg: 384x640 3 Boxess, 523.5ms
# image 4/7 d:\PYTHON PROJECTS\Box_Counting\Box_Count-3\valid\images\32_jpeg.rf.d3ed8776cb54ff3135c360cb4ee4ff4a.jpg: 384x640 18 Boxess, 442.6ms
# image 5/7 d:\PYTHON PROJECTS\Box_Counting\Box_Count-3\valid\images\33_jpeg.rf.ca4cbe55d7f3bd74339f32126de8b1ce.jpg: 480x640 6 Boxess, 684.7ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f"runs/detect/predict/*.jpg"):
    display(Image(filename=image_path, height=600))
    print("\n")
